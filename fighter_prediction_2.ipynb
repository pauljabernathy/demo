# %% [markdown]
# In this notebook, we will attempt to predict the outcome of fights before they happen based on the previous records of the fighters.

# %% [markdown]
# TODO:  use_train_test split to split into training and testing set.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import fighters_cleanser
import constants

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
fights = fighters_cleanser.load_cleanse_and_merge(constants.DEFAULT_FIGHTERS_FILE_NAME, constants.DEFAULT_FIGHTS_FILE_NAME)
fights.shape
# Out:
# (4393, 142)

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_kd  b_kd  r_sig_str  b_sig_str  \
# 0      Henry Cejudo  Marlon Moraes     0     0  90 of 171  57 of 119
# 1     Jimmie Rivera  Marlon Moraes     0     1     0 of 3     7 of 9
# 2       John Dodson  Marlon Moraes     1     0  43 of 105  45 of 131
# 3  Raphael Assuncao  Marlon Moraes     0     1    2 of 12   10 of 23
# 4  Raphael Assuncao  Marlon Moraes     0     0  43 of 134  44 of 150
#
#    r_sig_str_pct  b_sig_str_pct r_total_str b_total_str  ...  age_diff  \
# 0             52             47   99 of 182   59 of 121  ...  1.210959
# 1              0             77      0 of 3      7 of 9  ... -1.175342
# 2             40             34   47 of 109   45 of 131  ...  3.583562
# 3             16             43     3 of 13    12 of 25  ...  5.775342
# 4             32             29   43 of 134   44 of 150  ...  5.775342
#
#   height_diff  weight_diff  reach_diff  r_prior_wins  r_prior_losses  \
# 0          -2            0          -3            12               6
# 1          -2            0           1             9               4
# 2          -3            0          -1            12               7
# 3          -1            0          -1            15               6
# 4          -1            0          -1            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties
# 0             0             8               5             0
# 1             0             6               5             0
# 2             0             4               5             0
# 3             0             7               5             0
# 4             0             4               4             0
#
# [5 rows x 142 columns]

# %% [markdown]
# A few ways to do it.
#
# 1. Feed it into a DNN model, the hot thing in ML these days.
#
# 2. Logistic regression.
#
# 3. Just look at the record and go with the one with a higher percentage.
#
# 4. A slightly more advanced approach of 3, where you have some sort of bayesian calculation.
#
# The first two are the two things I have done elsewhere in this project.  They have some potential to work, but I don't like them as much.  I guess at least part of that is that they are not "explainable."
#
# 3 is pretty shallow and probably won't work, because someone with little to no previous record can't realistically be predicted this way.
#
# 4 is my favorite, but will require some thinking about how to go about assigning probabilities to people with little to no past record.
#
# I think I will start with 4 actually.

# %% [markdown]
# The approach for 4 will be that everyone starts with some fictitious record, with an even number of wins and losses and possibly a tie.  Something like 4-4, but we will experiment with it.  This will, if the red fighter is 10=0 and the blue fighter is 0-10, the model will still show some small probability that blue will win.  But as the number of fights each fighter has done, the less the fictious probability matters.

# %%
# remove some columns we don't need
#list(fights.columns)
columns_to_use = ['r_fighter','b_fighter','r_prior_wins', 'r_prior_losses', 'r_prior_ties', 'b_prior_wins', 'b_prior_losses', 'b_prior_ties', 'winner', 'loser', 'r_b_winner']
fights = fights[columns_to_use]
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser r_b_winner
# 0     Marlon Moraes          r
# 1     Jimmie Rivera          b
# 2       John Dodson          b
# 3  Raphael Assuncao          b
# 4     Marlon Moraes          r

# %%
#fights.to_csv('fights_backup.csv', index=False)

# %%
#fights_backup = pd.read_csv('fights_backup.csv')
#fights_backup.head()

# %%
def add_probs_for_row(row):
    total_prior_fights = row[['r_prior_wins', 'r_prior_losses', 'r_prior_ties', 'b_prior_wins', 'b_prior_losses', 'b_prior_ties']].sum()
    row['r_win_prob'] = row.r_prior_wins / total_prior_fights
    row['r_loss_prob'] = row.r_prior_losses / total_prior_fights
    row['r_tie_prob'] = row.r_prior_ties / total_prior_fights
    row['b_win_prob'] = row.b_prior_wins / total_prior_fights
    row['b_loss_prob'] = row.b_prior_losses / total_prior_fights
    row['b_tie_prob'] = row.b_prior_ties / total_prior_fights
    return row

# %%
def add_probs(fights_df):
    fights_df['r_win_prob'] = 0
    fights_df['r_loss_prob'] = 0
    fights_df['r_tie_prob'] = 0
    fights_df['b_win_prob'] = 0
    fights_df['b_loss_prob'] = 0
    fights_df['b_tie_prob'] = 0
    fights_df = fights_df.apply(lambda row: add_probs_for_row(row), axis=1)
    return fights_df

# %%
fights = add_probs(fights)

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser r_b_winner  r_win_prob  r_loss_prob  r_tie_prob  \
# 0     Marlon Moraes          r    0.387097     0.193548         0.0
# 1     Jimmie Rivera          b    0.375000     0.166667         0.0
# 2       John Dodson          b    0.428571     0.250000         0.0
# 3  Raphael Assuncao          b    0.454545     0.181818         0.0
# 4     Marlon Moraes          r    0.461538     0.230769         0.0
#
#    b_win_prob  b_loss_prob  b_tie_prob
# 0    0.258065     0.161290         0.0
# 1    0.250000     0.208333         0.0
# 2    0.142857     0.178571         0.0
# 3    0.212121     0.151515         0.0
# 4    0.153846     0.153846         0.0

# %%
add_probs_for_row(fights.iloc[0])
# Out:
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# r_fighter          Henry Cejudo
# b_fighter         Marlon Moraes
# r_prior_wins                 12
# r_prior_losses                6
# r_prior_ties                  0
# b_prior_wins                  8
# b_prior_losses                5
# b_prior_ties                  0
# winner             Henry Cejudo
# loser             Marlon Moraes
# r_b_winner                    r
# r_win_prob             0.387097
# r_loss_prob            0.193548
# r_tie_prob                    0
# b_win_prob             0.258065
# b_loss_prob             0.16129
# b_tie_prob                    0
# Name: 0, dtype: object

# %%
12 + 6 + 8 + 5
# Out:
# 31

# %%
12/31, 6/31, 8/31,5/31
# Out:
# (0.3870967741935484,
#  0.1935483870967742,
#  0.25806451612903225,
#  0.16129032258064516)

# %%
fights['r_win_prob'] = 0
fights['r_loss_prob'] = 0
fights['r_tie_prob'] = 0
fights['b_win_prob'] = 0
fights['b_loss_prob'] = 0
fights['b_tie_prob'] = 0

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser r_b_winner  r_win_prob  r_loss_prob  r_tie_prob  \
# 0     Marlon Moraes          r           0            0           0
# 1     Jimmie Rivera          b           0            0           0
# 2       John Dodson          b           0            0           0
# 3  Raphael Assuncao          b           0            0           0
# 4     Marlon Moraes          r           0            0           0
#
#    b_win_prob  b_loss_prob  b_tie_prob
# 0           0            0           0
# 1           0            0           0
# 2           0            0           0
# 3           0            0           0
# 4           0            0           0

# %%
add_probs_for_row(fights.iloc[0])
# Out:
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\paulj_1e1uzlz\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# r_fighter          Henry Cejudo
# b_fighter         Marlon Moraes
# r_prior_wins                 12
# r_prior_losses                6
# r_prior_ties                  0
# b_prior_wins                  8
# b_prior_losses                5
# b_prior_ties                  0
# winner             Henry Cejudo
# loser             Marlon Moraes
# r_b_winner                    r
# r_win_prob             0.387097
# r_loss_prob            0.193548
# r_tie_prob                    0
# b_win_prob             0.258065
# b_loss_prob             0.16129
# b_tie_prob                    0
# Name: 0, dtype: object

# %%
fights = fights.apply(lambda row: add_probs_for_row(row), axis=1)

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser r_b_winner  r_win_prob  r_loss_prob  r_tie_prob  \
# 0     Marlon Moraes          r    0.387097     0.193548         0.0
# 1     Jimmie Rivera          b    0.375000     0.166667         0.0
# 2       John Dodson          b    0.428571     0.250000         0.0
# 3  Raphael Assuncao          b    0.454545     0.181818         0.0
# 4     Marlon Moraes          r    0.461538     0.230769         0.0
#
#    b_win_prob  b_loss_prob  b_tie_prob
# 0    0.258065     0.161290         0.0
# 1    0.250000     0.208333         0.0
# 2    0.142857     0.178571         0.0
# 3    0.212121     0.151515         0.0
# 4    0.153846     0.153846         0.0

# %%
fights.r_won
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-6b8ebb863da9> in <module>
# ----> 1 fights.r_won
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'r_won'

# %%
fights['r_guess'] = fights.r_win_prob > fights.b_win_prob

# %%
fights['guess'] = fights.r_guess.apply(lambda x: 'r' if x == True else 'b')

# %%
fights.guess
# Out:
# 0       r
# 1       r
# 2       r
# 3       r
# 4       r
#        ..
# 4388    r
# 4389    b
# 4390    b
# 4391    b
# 4392    b
# Name: guess, Length: 4393, dtype: object

# %%
(fights.r_b_winner == fights.guess).sum()
# Out:
# 2147

# %%
fights.shape[0]
# Out:
# 4393

# %%
(fights.r_b_winner == fights.guess).sum() / fights.shape[0]
# Out:
# 0.4887320737536991

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser r_b_winner  r_win_prob  r_loss_prob  r_tie_prob  \
# 0     Marlon Moraes          r    0.387097     0.193548         0.0
# 1     Jimmie Rivera          b    0.375000     0.166667         0.0
# 2       John Dodson          b    0.428571     0.250000         0.0
# 3  Raphael Assuncao          b    0.454545     0.181818         0.0
# 4     Marlon Moraes          r    0.461538     0.230769         0.0
#
#    b_win_prob  b_loss_prob  b_tie_prob  r_guess guess
# 0    0.258065     0.161290         0.0     True     r
# 1    0.250000     0.208333         0.0     True     r
# 2    0.142857     0.178571         0.0     True     r
# 3    0.212121     0.151515         0.0     True     r
# 4    0.153846     0.153846         0.0     True     r

# %% [markdown]
# So this has a less than 50% accuracy.  Not what I was hoping for.

# %% [markdown]
# How often is the one with a greater prior win percentage the one who is labeled "Red"?

# %%
(fights['r_win_prob'] > fights['b_win_prob']).sum() / fights.shape[0]
# Out:
# 0.516958798087867

# %% [markdown]
# So only a little over half the time.
#
# So...how do they determine who is Red and who is Blue?  We already know that Red wins something like 2/3 of the time, so there must be a little bit of accuracy.

# %% [markdown]
# The way I did things above is, on second look, probably not the best way to calculate probablities of winning.  It simply adds up the total number of wins, losses and ties for each player and divides each number by the total number of fights.  Let's say for example that fighter R was 12-6-0 and B was 6-0-0.  It would first convert that to 16-10-0 and 10-4-0, and the probabilities would be .4, .25, 0 for R and .25, .1, 0 for B.  This means R has a greater estimated probability of winning, even though B was 6 and 0.
#
# The thing that clued me in that something in this calcuation was weird was seeing a row up there (row 2, John Dodson vs Marlon Moraes) where R had both a higher chance of winning...and of losing.  This method calculates the probabilities that, if you were to randomly select a prior that one of them had been in, what the outcome out be.  It also does not factor in any previous matches between the two.  I don't think it calculates anything like the probability of winning the next match.
#
# Probilities for both winning and losing, are weighted toward the one who has more fights in their record.
#
# What can be done about the case where one person has more fights than the other?  Which is most fights.  I still like the idea of adding ficticious fights to the record to smooth out the randomness.
#
# 1. Not worry about it.  Once the set of ficticious fights has been added, just use the win percentage as is, even if one person has a bigger record.
# 2. Add a different number of ficticous fights to the one with the smaller record so that they both have the same number of fights, then do the calculation above.  This is of course an estimate and could be totally wrong, but might be a good enough estimate to work.
# 3. Some other more complicated math that takes into account a margin of uncertainty.
# 4. Abandon the ficticious fights idea and look at how people do with a 0-0-0 record, 1-0-0, record, and so forth.  I suspect there is not enough sample size and each record combination will only appear a few times.
#
# Another way is to abandon the idea of looking only at past record numbers and looking also at who each person has fought - each other? opponents with good records? opponents with bad records? etc.  A lot more complicated.

# %%
r0 = pd.Series([12, 6, 0])
b0 = pd.Series([6, 0, 0])

# %%
r = pd.Series([16, 10, 0])
b = pd.Series([10, 4, 0])
r, b
# Out:
# (0    16
#  1    10
#  2     0
#  dtype: int64,
#  0    10
#  1     4
#  2     0
#  dtype: int64)

# %%
s = r.sum() + b.sum()
s
# Out:
# 40

# %%
r / s, b/s
# Out:
# (0    0.40
#  1    0.25
#  2    0.00
#  dtype: float64,
#  0    0.25
#  1    0.10
#  2    0.00
#  dtype: float64)

# %% [markdown]
# Let's look at 2 above.

# %%
r0, b0
# Out:
# (0    12
#  1     6
#  2     0
#  dtype: int64,
#  0    6
#  1    0
#  2    0
#  dtype: int64)

# %%
r0.sum(), b0.sum(), r.sum(), b.sum()
# Out:
# (18, 6, 26, 14)

# %% [markdown]
# We could add ficticious fights to B only, or add additional after adding the same amount to everyone.  Let's look at both.
#
# First option

# %%
r0.sum() - b0.sum()
# Out:
# 12

# %%
# => neet to add 12 ficticious fights to B.  Just do 6 and 6.  Of course, this won't work if there is an odd number of fights.
b2 = b0 + [6, 6, 0]
b2
# Out:
# 0    12
# 1     6
# 2     0
# dtype: int64

# %%
# If this were the true record of both, the calculation above would work.  In this case, both would have an equal chance of winning, which I still find suspicious because I still suspect B has a greater chance.

# %%
# using extra ficticious fights
r, b
# Out:
# (0    16
#  1    10
#  2     0
#  dtype: int64,
#  0    10
#  1     4
#  2     0
#  dtype: int64)

# %%
r.sum() - b.sum()
# Out:
# 12

# %%
# again, give B 12 more ficticious fights

# %%
b3 = b + [6, 6, 0]
b3
# Out:
# 0    16
# 1    10
# 2     0
# dtype: int64

# %% [markdown]
# Again, they have the same chances.  I think I picked a bad example by having R have twice as many wins as B so that when I added the ficticious fights, the numbers matched up to well.  I don't know how much that matters

# %% [markdown]
# Now look at option 1 above, where the initial value of ficticious fights is enough to give us enough confidence in their winning percentages.

# %%
fights
# Out:
#              r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0         Henry Cejudo  Marlon Moraes            12               6
# 1        Jimmie Rivera  Marlon Moraes             9               4
# 2          John Dodson  Marlon Moraes            12               7
# 3     Raphael Assuncao  Marlon Moraes            15               6
# 4     Raphael Assuncao  Marlon Moraes            12               6
# ...                ...            ...           ...             ...
# 4388        Tim Sylvia    Jeff Monson             6               6
# 4389      Eric Schafer  Rob MacDonald             4               4
# 4390     Jason Lambert  Rob MacDonald             4               4
# 4391        Dale Hartt     Corey Hill             4               5
# 4392   Justin Buchholz     Corey Hill             4               5
#
#       r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties  \
# 0                0             8               5             0
# 1                0             6               5             0
# 2                0             4               5             0
# 3                0             7               5             0
# 4                0             4               4             0
# ...            ...           ...             ...           ...
# 4388             0             5               5             0
# 4389             0             4               5             0
# 4390             0             4               4             0
# 4391             0             4               5             0
# 4392             0             4               4             0
#
#                 winner             loser r_b_winner  r_win_prob  r_loss_prob  \
# 0         Henry Cejudo     Marlon Moraes          r    0.387097     0.193548
# 1        Marlon Moraes     Jimmie Rivera          b    0.375000     0.166667
# 2        Marlon Moraes       John Dodson          b    0.428571     0.250000
# 3        Marlon Moraes  Raphael Assuncao          b    0.454545     0.181818
# 4     Raphael Assuncao     Marlon Moraes          r    0.461538     0.230769
# ...                ...               ...        ...         ...          ...
# 4388        Tim Sylvia       Jeff Monson          r    0.272727     0.272727
# 4389      Eric Schafer     Rob MacDonald          r    0.235294     0.235294
# 4390     Jason Lambert     Rob MacDonald          r    0.250000     0.250000
# 4391        Dale Hartt        Corey Hill          r    0.222222     0.277778
# 4392   Justin Buchholz        Corey Hill          r    0.235294     0.294118
#
#       r_tie_prob  b_win_prob  b_loss_prob  b_tie_prob  r_guess guess
# 0            0.0    0.258065     0.161290         0.0     True     r
# 1            0.0    0.250000     0.208333         0.0     True     r
# 2            0.0    0.142857     0.178571         0.0     True     r
# 3            0.0    0.212121     0.151515         0.0     True     r
# 4            0.0    0.153846     0.153846         0.0     True     r
# ...          ...         ...          ...         ...      ...   ...
# 4388         0.0    0.227273     0.227273         0.0     True     r
# 4389         0.0    0.235294     0.294118         0.0    False     b
# 4390         0.0    0.250000     0.250000         0.0    False     b
# 4391         0.0    0.222222     0.277778         0.0    False     b
# 4392         0.0    0.235294     0.235294         0.0    False     b
#
# [4393 rows x 19 columns]

# %% [markdown]
# => Calculate prior win, loss, tie percentages.  Go with the one with the higher win percentage, or greatest difference between win and loss percentages (since ties can mean using only win percentage might be a little wrong).

# %%
r_total_fights = fights.r_prior_wins + fights.r_prior_losses + fights.r_prior_ties
b_total_fights = fights.b_prior_wins + fights.b_prior_losses + fights.b_prior_ties

# %%
fights['r_total_fights'] = r_total_fights
fights['b_total_fights'] = b_total_fights

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser  ... r_win_prob  r_loss_prob  r_tie_prob  b_win_prob  \
# 0     Marlon Moraes  ...   0.387097     0.193548         0.0    0.258065
# 1     Jimmie Rivera  ...   0.375000     0.166667         0.0    0.250000
# 2       John Dodson  ...   0.428571     0.250000         0.0    0.142857
# 3  Raphael Assuncao  ...   0.454545     0.181818         0.0    0.212121
# 4     Marlon Moraes  ...   0.461538     0.230769         0.0    0.153846
#
#    b_loss_prob  b_tie_prob  r_guess  guess r_total_fights  b_total_fights
# 0     0.161290         0.0     True      r             18              13
# 1     0.208333         0.0     True      r             13              11
# 2     0.178571         0.0     True      r             19               9
# 3     0.151515         0.0     True      r             21              12
# 4     0.153846         0.0     True      r             18               8
#
# [5 rows x 21 columns]

# %%
fights['r_win_pct'] = fights.r_prior_wins / fights.r_total_fights
fights['r_loss_pct'] = fights.r_prior_losses / fights.r_total_fights
fights['r_tie_pct'] = fights.r_prior_ties / fights.r_total_fights

fights['b_win_pct'] = fights.b_prior_wins / fights.b_total_fights
fights['b_loss_pct'] = fights.b_prior_losses / fights.b_total_fights
fights['b_tie_pct'] = fights.b_prior_ties / fights.b_total_fights

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser  ... r_guess  guess r_total_fights  b_total_fights  \
# 0     Marlon Moraes  ...    True      r             18              13
# 1     Jimmie Rivera  ...    True      r             13              11
# 2       John Dodson  ...    True      r             19               9
# 3  Raphael Assuncao  ...    True      r             21              12
# 4     Marlon Moraes  ...    True      r             18               8
#
#    r_win_pct  r_loss_pct  r_tie_pct  b_win_pct  b_loss_pct  b_tie_pct
# 0   0.666667    0.333333        0.0   0.615385    0.384615        0.0
# 1   0.692308    0.307692        0.0   0.545455    0.454545        0.0
# 2   0.631579    0.368421        0.0   0.444444    0.555556        0.0
# 3   0.714286    0.285714        0.0   0.583333    0.416667        0.0
# 4   0.666667    0.333333        0.0   0.500000    0.500000        0.0
#
# [5 rows x 21 columns]

# %%
fights.columns
# Out:
# Index(['r_fighter', 'b_fighter', 'r_prior_wins', 'r_prior_losses',
#        'r_prior_ties', 'b_prior_wins', 'b_prior_losses', 'b_prior_ties',
#        'winner', 'loser', 'r_b_winner', 'r_win_prob', 'r_loss_prob',
#        'r_tie_prob', 'b_win_prob', 'b_loss_prob', 'b_tie_prob', 'r_guess',
#        'guess', 'r_total_fights', 'b_total_fights', 'r_win_pct', 'r_loss_pct',
#        'r_tie_pct', 'b_win_pct', 'b_loss_pct', 'b_tie_pct'],
#       dtype='object')

# %%
fights = fights.drop(['r_win_prob', 'r_loss_prob', 'r_tie_prob', 'b_win_prob', 'b_loss_prob', 'b_tie_prob'], axis=1)

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser  ... r_guess  guess r_total_fights  b_total_fights  \
# 0     Marlon Moraes  ...    True      r             18              13
# 1     Jimmie Rivera  ...    True      r             13              11
# 2       John Dodson  ...    True      r             19               9
# 3  Raphael Assuncao  ...    True      r             21              12
# 4     Marlon Moraes  ...    True      r             18               8
#
#    r_win_pct  r_loss_pct  r_tie_pct  b_win_pct  b_loss_pct  b_tie_pct
# 0   0.666667    0.333333        0.0   0.615385    0.461538        0.0
# 1   0.692308    0.307692        0.0   0.545455    0.363636        0.0
# 2   0.631579    0.368421        0.0   0.444444    0.777778        0.0
# 3   0.714286    0.285714        0.0   0.583333    0.500000        0.0
# 4   0.666667    0.333333        0.0   0.500000    0.750000        0.0
#
# [5 rows x 21 columns]

# %%
fights[fights.r_tie_pct > 0].shape[0]
# Out:
# 340

# %%
fights[fights.b_tie_pct > 0].shape[0]
# Out:
# 292

# %%
fights.shape[0]
# Out:
# 4393

# %%
fights[fights.r_tie_pct != fights.b_tie_pct].shape[0]
# Out:
# 583

# %%
fights[(fights.r_tie_pct > 0) | (fights.b_tie_pct > 0)].head(80)
# Out:
#               r_fighter        b_fighter  r_prior_wins  r_prior_losses  \
# 10         Alex Caceres    Sergio Pettis             8               7
# 15         Yaotzin Meza    Sergio Pettis             5               5
# 19   Demetrious Johnson      Wilson Reis            17               5
# 24         Henry Cejudo      Chico Camus             6               4
# 25         Brad Pickett      Chico Camus             8               8
# ..                  ...              ...           ...             ...
# 401    Charles Oliveira  Christos Giagos            14              12
# 403       Mizuto Hirota  Christos Giagos             5               8
# 414          Stevie Ray  Leonardo Santos            10               7
# 417         Darren Till     Jessin Ayari             5               4
# 423    Charles Oliveira      Paul Felder            13              11
#
#      r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties  \
# 10              1             5               4             0
# 15              1             5               5             0
# 19              1            10               6             0
# 24              0             7               6             1
# 25              0             6               6             1
# ..            ...           ...             ...           ...
# 401             1             5               6             0
# 403             1             5               7             0
# 414             0             9               4             1
# 417             1             5               4             0
# 423             1            10               7             0
#
#                  winner             loser  ... r_guess  guess r_total_fights  \
# 10         Alex Caceres     Sergio Pettis  ...    True      r             16
# 15        Sergio Pettis      Yaotzin Meza  ...   False      b             11
# 19   Demetrious Johnson       Wilson Reis  ...    True      r             23
# 24         Henry Cejudo       Chico Camus  ...   False      b             10
# 25          Chico Camus      Brad Pickett  ...    True      r             16
# ..                  ...               ...  ...     ...    ...            ...
# 401    Charles Oliveira   Christos Giagos  ...    True      r             27
# 403     Christos Giagos     Mizuto Hirota  ...   False      b             14
# 414     Leonardo Santos        Stevie Ray  ...    True      r             17
# 417         Darren Till      Jessin Ayari  ...   False      b             10
# 423         Paul Felder  Charles Oliveira  ...    True      r             25
#
#      b_total_fights  r_win_pct  r_loss_pct  r_tie_pct  b_win_pct  b_loss_pct  \
# 10                9   0.500000    0.437500   0.062500   0.555556    0.444444
# 15               10   0.454545    0.454545   0.090909   0.500000    0.500000
# 19               16   0.739130    0.217391   0.043478   0.625000    0.375000
# 24               14   0.600000    0.400000   0.000000   0.500000    0.428571
# 25               13   0.500000    0.500000   0.000000   0.461538    0.461538
# ..              ...        ...         ...        ...        ...         ...
# 401              11   0.518519    0.444444   0.037037   0.454545    0.545455
# 403              12   0.357143    0.571429   0.071429   0.416667    0.583333
# 414              14   0.588235    0.411765   0.000000   0.642857    0.285714
# 417               9   0.500000    0.400000   0.100000   0.555556    0.444444
# 423              17   0.520000    0.440000   0.040000   0.588235    0.411765
#
#      b_tie_pct
# 10    0.000000
# 15    0.000000
# 19    0.000000
# 24    0.071429
# 25    0.076923
# ..         ...
# 401   0.000000
# 403   0.000000
# 414   0.071429
# 417   0.000000
# 423   0.000000
#
# [80 rows x 21 columns]

# %%
fights['r_wldiff_pct'] = fights.r_win_pct - fights.r_loss_pct
fights['b_wldiff_pct'] = fights.b_win_pct - fights.b_loss_pct

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser  ... r_total_fights  b_total_fights r_win_pct  r_loss_pct  \
# 0     Marlon Moraes  ...             18              13  0.666667    0.333333
# 1     Jimmie Rivera  ...             13              11  0.692308    0.307692
# 2       John Dodson  ...             19               9  0.631579    0.368421
# 3  Raphael Assuncao  ...             21              12  0.714286    0.285714
# 4     Marlon Moraes  ...             18               8  0.666667    0.333333
#
#    r_tie_pct  b_win_pct  b_loss_pct  b_tie_pct  r_wldiff_pct  b_wldiff_pct
# 0        0.0   0.615385    0.384615        0.0      0.333333      0.230769
# 1        0.0   0.545455    0.454545        0.0      0.384615      0.090909
# 2        0.0   0.444444    0.555556        0.0      0.263158     -0.111111
# 3        0.0   0.583333    0.416667        0.0      0.428571      0.166667
# 4        0.0   0.500000    0.500000        0.0      0.333333      0.000000
#
# [5 rows x 23 columns]

# %%
fights['guess_opt1'] = fights.apply(lambda row: 'r' if row.r_wldiff_pct > row.b_wldiff_pct else 'b', axis=1)

# %%
fights.head()
# Out:
#           r_fighter      b_fighter  r_prior_wins  r_prior_losses  \
# 0      Henry Cejudo  Marlon Moraes            12               6
# 1     Jimmie Rivera  Marlon Moraes             9               4
# 2       John Dodson  Marlon Moraes            12               7
# 3  Raphael Assuncao  Marlon Moraes            15               6
# 4  Raphael Assuncao  Marlon Moraes            12               6
#
#    r_prior_ties  b_prior_wins  b_prior_losses  b_prior_ties            winner  \
# 0             0             8               5             0      Henry Cejudo
# 1             0             6               5             0     Marlon Moraes
# 2             0             4               5             0     Marlon Moraes
# 3             0             7               5             0     Marlon Moraes
# 4             0             4               4             0  Raphael Assuncao
#
#               loser  ... b_total_fights  r_win_pct r_loss_pct  r_tie_pct  \
# 0     Marlon Moraes  ...             13   0.666667   0.333333        0.0
# 1     Jimmie Rivera  ...             11   0.692308   0.307692        0.0
# 2       John Dodson  ...              9   0.631579   0.368421        0.0
# 3  Raphael Assuncao  ...             12   0.714286   0.285714        0.0
# 4     Marlon Moraes  ...              8   0.666667   0.333333        0.0
#
#    b_win_pct  b_loss_pct  b_tie_pct  r_wldiff_pct  b_wldiff_pct  guess_opt1
# 0   0.615385    0.384615        0.0      0.333333      0.230769           r
# 1   0.545455    0.454545        0.0      0.384615      0.090909           r
# 2   0.444444    0.555556        0.0      0.263158     -0.111111           r
# 3   0.583333    0.416667        0.0      0.428571      0.166667           r
# 4   0.500000    0.500000        0.0      0.333333      0.000000           r
#
# [5 rows x 24 columns]

# %%
print(accuracy_score(fights.r_b_winner, fights.guess_opt1))
# Out:
# 0.5219667653084452

# %%
(fights.r_b_winner == fights.guess_opt1).sum() / fights.shape[0]
# Out:
# 0.5219667653084452

# %% [markdown]
# So, hardly better than the first try.  This is disappointing, and also perplexing since it uses the difference in win and loss percentages.  One option is to experiment with the number of ficticious fights (0, 5, 10, etc.).  If I do that, I'll need to put this process into a function so I don't have to keep doing the same manual process over and over.

# %%
fights[['r_prior_wins', 'r_prior_losses',
       'r_prior_ties', 'b_prior_wins', 'b_prior_losses', 'b_prior_ties', 'r_total_fights',
       'b_total_fights', 'r_win_pct', 'r_loss_pct', 'r_tie_pct', 'b_win_pct',
       'b_loss_pct', 'b_tie_pct', 'r_wldiff_pct', 'b_wldiff_pct',
       'guess_opt1', 'r_b_winner']].head(40)
# Out:
#     r_prior_wins  r_prior_losses  r_prior_ties  b_prior_wins  b_prior_losses  \
# 0             12               6             0             8               5
# 1              9               4             0             6               5
# 2             12               7             0             4               5
# 3             15               6             0             7               5
# 4             12               6             0             4               4
# 5             11               6             0            16               7
# 6             10               4             0            14               7
# 7             11               4             0             9               6
# 8              8               5             0             8               5
# 9              9               6             0            11               6
# 10             8               7             1             5               4
# 11            14               6             0            11               7
# 12             9               7             0            12               8
# 13             9               8             0             9               6
# 14            11               9             0             7               6
# 15             5               5             1             5               5
# 16             4               6             0             4               4
# 17             8               6             0            10               7
# 18             7               6             0             7               5
# 19            17               5             1            10               6
# 20             7               6             0             7               6
# 21             7               6             0             5               4
# 22             8               9             0             6               5
# 23             8               7             0             4               4
# 24             6               4             0             7               6
# 25             8               8             0             6               6
# 26             8               5             0             7               7
# 27             5               4             0             6               5
# 28             5               6             0             4               4
# 29             4               4             0             6               6
# 30             5               5             0             5               4
# 31             7              10             0             6               5
# 32             5               4             0             4               4
# 33             9               6             0             7               9
# 34             8               5             0             6               9
# 35             6               4             0             4               4
# 36             6               4             0             5               9
# 37             6               7             0             5               7
# 38             7               6             0             5               5
# 39             4               4             0             4               4
#
#     b_prior_ties  r_total_fights  b_total_fights  r_win_pct  r_loss_pct  \
# 0              0              18              13   0.666667    0.333333
# 1              0              13              11   0.692308    0.307692
# 2              0              19               9   0.631579    0.368421
# 3              0              21              12   0.714286    0.285714
# 4              0              18               8   0.666667    0.333333
# 5              0              17              23   0.647059    0.352941
# 6              0              14              21   0.714286    0.285714
# 7              0              15              15   0.733333    0.266667
# 8              0              13              13   0.615385    0.384615
# 9              0              15              17   0.600000    0.400000
# 10             0              16               9   0.500000    0.437500
# 11             0              20              18   0.700000    0.300000
# 12             0              16              20   0.562500    0.437500
# 13             0              17              15   0.529412    0.470588
# 14             0              20              13   0.550000    0.450000
# 15             0              11              10   0.454545    0.454545
# 16             0              10               8   0.400000    0.600000
# 17             0              14              17   0.571429    0.428571
# 18             0              13              12   0.538462    0.461538
# 19             0              23              16   0.739130    0.217391
# 20             0              13              13   0.538462    0.461538
# 21             0              13               9   0.538462    0.461538
# 22             0              17              11   0.470588    0.529412
# 23             0              15               8   0.533333    0.466667
# 24             1              10              14   0.600000    0.400000
# 25             1              16              13   0.500000    0.500000
# 26             1              13              15   0.615385    0.384615
# 27             1               9              12   0.555556    0.444444
# 28             0              11               8   0.454545    0.545455
# 29             0               8              12   0.500000    0.500000
# 30             0              10               9   0.500000    0.500000
# 31             0              17              11   0.411765    0.588235
# 32             0               9               8   0.555556    0.444444
# 33             1              15              17   0.600000    0.400000
# 34             1              13              16   0.615385    0.384615
# 35             1              10               9   0.600000    0.400000
# 36             1              10              15   0.600000    0.400000
# 37             1              13              13   0.461538    0.538462
# 38             1              13              11   0.538462    0.461538
# 39             0               8               8   0.500000    0.500000
#
#     r_tie_pct  b_win_pct  b_loss_pct  b_tie_pct  r_wldiff_pct  b_wldiff_pct  \
# 0    0.000000   0.615385    0.384615   0.000000      0.333333      0.230769
# 1    0.000000   0.545455    0.454545   0.000000      0.384615      0.090909
# 2    0.000000   0.444444    0.555556   0.000000      0.263158     -0.111111
# 3    0.000000   0.583333    0.416667   0.000000      0.428571      0.166667
# 4    0.000000   0.500000    0.500000   0.000000      0.333333      0.000000
# 5    0.000000   0.695652    0.304348   0.000000      0.294118      0.391304
# 6    0.000000   0.666667    0.333333   0.000000      0.428571      0.333333
# 7    0.000000   0.600000    0.400000   0.000000      0.466667      0.200000
# 8    0.000000   0.615385    0.384615   0.000000      0.230769      0.230769
# 9    0.000000   0.647059    0.352941   0.000000      0.200000      0.294118
# 10   0.062500   0.555556    0.444444   0.000000      0.062500      0.111111
# 11   0.000000   0.611111    0.388889   0.000000      0.400000      0.222222
# 12   0.000000   0.600000    0.400000   0.000000      0.125000      0.200000
# 13   0.000000   0.600000    0.400000   0.000000      0.058824      0.200000
# 14   0.000000   0.538462    0.461538   0.000000      0.100000      0.076923
# 15   0.090909   0.500000    0.500000   0.000000      0.000000      0.000000
# 16   0.000000   0.500000    0.500000   0.000000     -0.200000      0.000000
# 17   0.000000   0.588235    0.411765   0.000000      0.142857      0.176471
# 18   0.000000   0.583333    0.416667   0.000000      0.076923      0.166667
# 19   0.043478   0.625000    0.375000   0.000000      0.521739      0.250000
# 20   0.000000   0.538462    0.461538   0.000000      0.076923      0.076923
# 21   0.000000   0.555556    0.444444   0.000000      0.076923      0.111111
# 22   0.000000   0.545455    0.454545   0.000000     -0.058824      0.090909
# 23   0.000000   0.500000    0.500000   0.000000      0.066667      0.000000
# 24   0.000000   0.500000    0.428571   0.071429      0.200000      0.071429
# 25   0.000000   0.461538    0.461538   0.076923      0.000000      0.000000
# 26   0.000000   0.466667    0.466667   0.066667      0.230769      0.000000
# 27   0.000000   0.500000    0.416667   0.083333      0.111111      0.083333
# 28   0.000000   0.500000    0.500000   0.000000     -0.090909      0.000000
# 29   0.000000   0.500000    0.500000   0.000000      0.000000      0.000000
# 30   0.000000   0.555556    0.444444   0.000000      0.000000      0.111111
# 31   0.000000   0.545455    0.454545   0.000000     -0.176471      0.090909
# 32   0.000000   0.500000    0.500000   0.000000      0.111111      0.000000
# 33   0.000000   0.411765    0.529412   0.058824      0.200000     -0.117647
# 34   0.000000   0.375000    0.562500   0.062500      0.230769     -0.187500
# 35   0.000000   0.444444    0.444444   0.111111      0.200000      0.000000
# 36   0.000000   0.333333    0.600000   0.066667      0.200000     -0.266667
# 37   0.000000   0.384615    0.538462   0.076923     -0.076923     -0.153846
# 38   0.000000   0.454545    0.454545   0.090909      0.076923      0.000000
# 39   0.000000   0.500000    0.500000   0.000000      0.000000      0.000000
#
#    guess_opt1 r_b_winner
# 0           r          r
# 1           r          b
# 2           r          b
# 3           r          b
# 4           r          r
# 5           b          r
# 6           r          b
# 7           r          b
# 8           b          r
# 9           b          r
# 10          b          r
# 11          r          b
# 12          b          r
# 13          b          b
# 14          r          b
# 15          b          b
# 16          b          b
# 17          b          r
# 18          b          r
# 19          r          r
# 20          b          b
# 21          b          r
# 22          b          b
# 23          r          b
# 24          r          r
# 25          b          b
# 26          r          r
# 27          r          r
# 28          b          b
# 29          b          r
# 30          b          r
# 31          b          r
# 32          r          b
# 33          r          r
# 34          r          b
# 35          r          r
# 36          r          b
# 37          r          r
# 38          r          r
# 39          b       None
